# %% [markdown]
# ## Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Dataframes

# %%
path = r"/Users/katalysenko/Documents/Airbnb Analysis"

# %%
# Import of df

df = pd.read_csv(r"/Users/katalysenko/Documents/Airbnb Analysis/02 Data/Original Data/Airbnb Open Data.csv",index_col=False)
# Out:
# /var/folders/p4/8yql05j55jlgk_8dqfyzrk2r0000gn/T/ipykernel_97894/4252554502.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"/Users/katalysenko/Documents/Airbnb Analysis/02 Data/Original Data/Airbnb Open Data.csv",index_col=False)

# %% [markdown]
# ## Understand the Data

# %%
df.shape
# Out:
# (102599, 26)

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
# Dropping "host name" column. We can see that in our case, we have particularly sensitive data in the form of the "host name" columns, so we get rid of them before we start our analysis.

df = df.drop(['host name'], axis=1)

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified neighbourhood group neighbourhood       lat  \
# 0            unconfirmed            Brooklyn    Kensington  40.64749
# 1               verified           Manhattan       Midtown  40.75362
# 2                    NaN           Manhattan        Harlem  40.80902
# 3            unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4               verified           Manhattan   East Harlem  40.79851
#
#        long        country country code  ... service fee minimum nights  \
# ...

# %%
df.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %% [markdown]
# ## Clean the Data

# %%
df.rename(columns = {'NAME' : 'name'}, inplace = True)

# %%
# Dropping unnessesary columns


df = df.drop(['id','host id','house_rules','license'], axis=1)

# %%
df.head()
# Out:
#                                                name host_identity_verified  \
# 0                Clean & quiet apt home by the park            unconfirmed
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   neighbourhood group neighbourhood       lat      long        country  \
# 0            Brooklyn    Kensington  40.64749 -73.97237  United States
# 1           Manhattan       Midtown  40.75362 -73.98377  United States
# 2           Manhattan        Harlem  40.80902 -73.94190  United States
# 3            Brooklyn  Clinton Hill  40.68514 -73.95976  United States
# 4           Manhattan   East Harlem  40.79851 -73.94399  United States
#
#   country code instant_bookable cancellation_policy  ... Construction year  \
# ...

# %%
df.shape
# Out:
# (102599, 21)

# %%
# Check for missing values

missing_values = df.isnull().sum()

# %%
missing_values
# Out:
# name                                250
# host_identity_verified              289
# neighbourhood group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# country                             532
# country code                        131
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      409
# number of reviews                   183
# last review                       15893
# reviews per month                 15879
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# dtype: int64

# %%
# List of column names to check for NaN values

cols_to_check = ['name', 'host_identity_verified', 'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country', 'country code', 'instant_bookable', 'cancellation_policy', 'Construction year', 'price', 'service fee', 'minimum nights', 'number of reviews', 'last review', 'reviews per month', 'review rate number', 'calculated host listings count', 'availability 365']

# %%
cols_to_check
# Out:
# ['name',
#  'host_identity_verified',
#  'neighbourhood group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country code',
#  'instant_bookable',
#  'cancellation_policy',
#  'Construction year',
#  'price',
#  'service fee',
#  'minimum nights',
#  'number of reviews',
#  'last review',
#  'reviews per month',
#  'review rate number',
#  'calculated host listings count',
#  'availability 365']

# %%
df_clean = df[df[cols_to_check].notnull().all(axis=1)]

# %%
df_clean.shape
# Out:
# (84186, 21)

# %%
# Find duplicates

df_dups = df_clean[df_clean.duplicated()]

# %%
df_dups.shape
# Out:
# (3027, 21)

# %%
df = df_clean.drop_duplicates()

# %%
df.shape
# Out:
# (81159, 21)

# %%
#Check mixed-type columns 

for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
        
# No mixed-type columns

# %% [markdown]
# #  Saving and Exporting df

# %%
df_clean.to_csv(os.path.join(path, '02 Data','Prepared data', 'df_clean.csv'))
